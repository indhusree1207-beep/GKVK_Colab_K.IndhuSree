# %%
from google.colab import files
files.upload()
# Out:
#      <input type="file" id="files-27eb509e-dd67-42df-83ca-b32ccb3b8d7f" name="files[]" multiple disabled
#         style="border:none" />
#      <output id="result-27eb509e-dd67-42df-83ca-b32ccb3b8d7f">
#       Upload widget is only available when the cell has been executed in the
#       current browser session. Please rerun this cell to enable.
#       </output>
#       <script>// Copyright 2017 Google LLC
# //
# // Licensed under the Apache License, Version 2.0 (the "License");
# // you may not use this file except in compliance with the License.
# // You may obtain a copy of the License at
# //
# //      http://www.apache.org/licenses/LICENSE-2.0
# //
# // Unless required by applicable law or agreed to in writing, software
# // distributed under the License is distributed on an "AS IS" BASIS,
# // WITHOUT WARRANTIES OR CONDITIONS OF ANY KIND, either express or implied.
# // See the License for the specific language governing permissions and
# // limitations under the License.
#
# ...

# %%
#Reading a file     #read()

file=open("crop1.txt","r")
content=file.read()
print(file)
file.close()
# Out:
# <_io.TextIOWrapper name='crop1.txt' mode='r' encoding='utf-8'>

# %%
### readline()
#Reads only the first line (up to \n)
file = open("crop1.txt", "r")
print(file.readline())    #if we use the readline() method ..it will read one line at a time.
                          #Whereas read() method reads letter by letter
                          #readlines() means it reads all the lines
# Out:
# CRP_RICE_2026

# %%
file = open("crop1.txt", "r")
print(file.readline())
print(file.readline())
# Out:
# CRP_RICE_2026
#
# CRP_WHEAT_2025

# %%
file=open("crop1.txt","r")
for line in file:
  print(line.strip()) #strip() is used to remove any extra spaces or new line characters
file.close()
# Out:
# CRP_RICE_2026
# CRP_WHEAT_2025
# CRP_RICE_2027
# CRP_MAIZE_2024
# CRP_WHEAT_2023

# %%
with open("crop1.txt","r") as file:    #if we do not wish to use file.close() then we can use with open() as file: to avoid using file.close()
   for line in file:                   #`with`-->File closes automatically
    print(line.strip())
# Out:
# CRP_RICE_2026
# CRP_WHEAT_2025
# CRP_RICE_2027
# CRP_MAIZE_2024
# CRP_WHEAT_2023

# %%
from google.colab import files
files.upload()
# Out:
#      <input type="file" id="files-5981728b-d4f8-4af2-978a-50bc8d7121f5" name="files[]" multiple disabled
#         style="border:none" />
#      <output id="result-5981728b-d4f8-4af2-978a-50bc8d7121f5">
#       Upload widget is only available when the cell has been executed in the
#       current browser session. Please rerun this cell to enable.
#       </output>
#       <script>// Copyright 2017 Google LLC
# //
# // Licensed under the Apache License, Version 2.0 (the "License");
# // you may not use this file except in compliance with the License.
# // You may obtain a copy of the License at
# //
# //      http://www.apache.org/licenses/LICENSE-2.0
# //
# // Unless required by applicable law or agreed to in writing, software
# // distributed under the License is distributed on an "AS IS" BASIS,
# // WITHOUT WARRANTIES OR CONDITIONS OF ANY KIND, either express or implied.
# // See the License for the specific language governing permissions and
# // limitations under the License.
#
# ...

# %%
with open("crop.txt","r") as file:
  lines=file.readlines() #redlines()-reads the entire file at once and stores all lines in a list

for line in lines:
  print(line.strip())
# Out:
# Rice
# Wheat
# Maize
# Pulses

# %%
with open("crop.txt","r") as file:
  lines=file.readlines() #redlines()-reads the entire file at once and stores all lines in a list

for line in lines:
  print(line)       #Here without the strip() command there are extra spaces left
# Out:
# Rice
#
# Wheat
#
# Maize
#
# Pulses

# %%
file = open("crop.txt", "w")
file.write("Orange\n")
file.write("Mango\n")
print(file)
file.close()
# Out:
# <_io.TextIOWrapper name='crop.txt' mode='w' encoding='utf-8'>

# %%
with open("crop.txt","r") as  file:
 print(file.readlines())
# Out:
# ['Orange\n', 'Mango\n']

# %%
file=open("crop.txt","r")
print(file.read())
file.close()
# Out:
# Orange
# Mango
# Maize

# %%
file = open("crop.txt", "a")   # "a" menas append...means the new input will e added to the existing input
file.write("Maize\n")
print(file)
file.close()
# Out:
# <_io.TextIOWrapper name='crop.txt' mode='a' encoding='utf-8'>

# %%
file = open("crop.txt","r")
content=file.read()
print(content)
file.close()
# Out:
# Orange
# Mango
# Maize
# Maize

# %%
with open("crop.txt","r") as file:
  for line in file:
    print(line.strip())
# Out:
# Orange
# Mango
# Maize
# Maize

# %%
from google.colab import files
files.upload()
# Out:
#      <input type="file" id="files-fd851514-e3d6-4859-bc54-0d4e26954b86" name="files[]" multiple disabled
#         style="border:none" />
#      <output id="result-fd851514-e3d6-4859-bc54-0d4e26954b86">
#       Upload widget is only available when the cell has been executed in the
#       current browser session. Please rerun this cell to enable.
#       </output>
#       <script>// Copyright 2017 Google LLC
# //
# // Licensed under the Apache License, Version 2.0 (the "License");
# // you may not use this file except in compliance with the License.
# // You may obtain a copy of the License at
# //
# //      http://www.apache.org/licenses/LICENSE-2.0
# //
# // Unless required by applicable law or agreed to in writing, software
# // distributed under the License is distributed on an "AS IS" BASIS,
# // WITHOUT WARRANTIES OR CONDITIONS OF ANY KIND, either express or implied.
# // See the License for the specific language governing permissions and
# // limitations under the License.
#
# ...

# %%
with open("Persimmons1.txt","r") as file:
  for record in file:
    record=record.strip()
    print(record)
# Out:
# Pear is a good fruit
# Banana is seedless
# Although pear is good, buy its costly

# %%
 with open("Persimmons1.txt","r") as file:
  for record in file:
    record=record.strip()
    if "pear" in record.lower(): #--->This is just a condition....it says to print only the sentences/statements specifying pear
      print(record)
# Out:
# Pear is a good fruit
# Although pear is good, buy its costly

# %%
with open("Persimmons1.txt", "r") as file:
    for record in file:
        record = record.strip()
        if "pear" in record:    #because .lower() is not mentioned here....compiler considers Pear and pear ad two different values
            print(record)
# Out:
# Although pear is good, buy its costly

# %%
#split() divides a string into multiple parts and returns a list.
#string.split(separator)

data="Rice Wheat Maize"
result=data.split()
print(result)
# Out:
# ['Rice', 'Wheat', 'Maize']

# %%
#split() divides a string into multiple parts and returns a list.
#string.split(separator)

data = "Rice:Wheat:Maize"
result = data.split(':') #divide the string at ":" this symbol
print(result)
# Out:
# ['Rice', 'Wheat', 'Maize']

# %%
line = "Rice,Wheat,Maize,Pulses"
crops = line.split()
print(crops)
# Out:
# ['Rice,Wheat,Maize,Pulses']

# %%
line = "Rice,Wheat,Maize,Pulses"
crops = line.split(",")
print(crops)
# Out:
# ['Rice', 'Wheat', 'Maize', 'Pulses']

# %%
from google.colab import files
files.upload()
# Out:
#      <input type="file" id="files-a225f44d-d7ab-47e2-b827-d5f1bde91841" name="files[]" multiple disabled
#         style="border:none" />
#      <output id="result-a225f44d-d7ab-47e2-b827-d5f1bde91841">
#       Upload widget is only available when the cell has been executed in the
#       current browser session. Please rerun this cell to enable.
#       </output>
#       <script>// Copyright 2017 Google LLC
# //
# // Licensed under the Apache License, Version 2.0 (the "License");
# // you may not use this file except in compliance with the License.
# // You may obtain a copy of the License at
# //
# //      http://www.apache.org/licenses/LICENSE-2.0
# //
# // Unless required by applicable law or agreed to in writing, software
# // distributed under the License is distributed on an "AS IS" BASIS,
# // WITHOUT WARRANTIES OR CONDITIONS OF ANY KIND, either express or implied.
# // See the License for the specific language governing permissions and
# // limitations under the License.
#
# ...

# %%
#Using split() during file handling
with open("crop_data.txt","r") as file:
  for line in file:
    fields=line.strip().split(",")
    print(fields)
# Out:
# ['CRP_RICE_2026', 'Rice', 'Kharif', 'High']
# ['CRP_WHEAT_2025', 'Wheat', 'Rabi', 'Medium']

# %%
#AQccessing split data

with open("crop_data.txt","r") as file:
  for line in file:
    fields=line.strip().split(",")

    crop_code=fields[0]
    crop_name=fields[1]
    season=fields[2]
    yield_level=fields[3]

    print(crop_code,crop_name,season,yield_level)
# Out:
# CRP_RICE_2026 Rice Kharif High
# CRP_WHEAT_2025 Wheat Rabi Medium

# %%
#AQccessing split data

with open("crop_data.txt","r") as file:
  for line in file:
    fields=line.strip().split(",")

    crop_code=fields[0]
    crop_name=fields[1]
    season=fields[2]
    yield_level=fields[3]

    print(crop_code,crop_name,season,yield_level)
print(type(line.split(",")))     #All the strings that are split are stored as list in the computer memory
# Out:
# CRP_RICE_2026 Rice Kharif High
# CRP_WHEAT_2025 Wheat Rabi Medium
# <class 'list'>
