# %%
namelist=["Harsh","Pratik","Bob","Dhruv"]
pos=namelist.index("Bob")
print(pos*3)
# Out:
# 6

# %%
namelist=["Harsh","Pratik","Bob","Dhruv"]
pos=namelist.index("GeeksforGeeks")
print(pos*3)
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# /tmp/ipython-input-514866395.py in <cell line: 0>()
#       1 namelist=["Harsh","Pratik","Bob","Dhruv"]
# ----> 2 pos=namelist.index("GeeksforGeeks")
#       3 print(pos*3)
#
# ValueError: 'GeeksforGeeks' is not in list

# %%
a=[1,2,3,4]
b=[5,6,7]
a.append(b)
print(a)
# Out:
# [1, 2, 3, 4, [5, 6, 7]]

# %%
a=[1,2,3,4]
b=[5,6,7]
a.extend(b)
print(a)
# Out:
# [1, 2, 3, 4, 5, 6, 7]
