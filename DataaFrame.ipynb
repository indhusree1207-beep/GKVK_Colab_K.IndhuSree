# %%
import pandas as pd

# 1. Create Sample Agricultural Data
data = {
    'Region': ['North', 'South', 'North', 'East', 'South', 'North'],
    'Crop': ['Wheat', 'Corn', 'Wheat', 'Rice', 'Corn', 'Wheat'],
    'Yield_Tons': [150, 200, 170, 300, 210, 160],
    'Acres': [50, 80, 55, 100, 85, 52]
}
df = pd.DataFrame(data)
print(df)
# Out:
#   Region   Crop  Yield_Tons  Acres
# 0  North  Wheat         150     50
# 1  South   Corn         200     80
# 2  North  Wheat         170     55
# 3   East   Rice         300    100
# 4  South   Corn         210     85
# 5  North  Wheat         160     52
