# %%
farm_data=[
    [1,"Rice",45],
    [2,"Wheat",40],
    [3,"Maize",60]
    ]

print(farm_data)
print(farm_data[0])
print(farm_data[0][1])
print(farm_data[1][1])
print(farm_data[2][2])
# Out:
# [[1, 'Rice', 45], [2, 'Wheat', 40], [3, 'Maize', 60]]
# [1, 'Rice', 45]
# Rice
# Wheat
# 60

# %%
farm_data= [[1,"Rice",45], [2,"Wheat",40],[3,"Maize",60]]

print(farm_data)
# Out:
# [[1, 'Rice', 45], [2, 'Wheat', 40], [3, 'Maize', 60]]

# %%
yield_data=[
    ["Rice",3200],
    ["Wheat",2000],
    ["Maize",3500]
]
for crop in yield_data:
  print(crop[0],"yield:",crop[1],"kg/ha")
# Out:
# Rice yield: 3200 kg/ha
# Wheat yield: 2000 kg/ha
# Maize yield: 3500 kg/ha

# %%
expenses=[
    ["Day 1",[1200,600,200]],
    ["Day 2",[1300,400,300]],
    ["Day 3",[1400,300,350]]
]
print("DAILY EXPENSES ")
for day in expenses:
  print(day[0],"total",sum(day[1]))
# Out:
# DAILY EXPENSES
# Day 1 total 2000
# Day 2 total 2000
# Day 3 total 2050

# %%
crop_plan=[["Kharif",["Rice","Maize"]],["Rabi",["Wheat","Gram"]],["Zaid",["Vegetables"]]]
print(crop_plan[0][1][0])
print(crop_plan[1][0],":",crop_plan[1][1][0])
# Out:
# Rice
# Rabi : Wheat

# %%
def expenses_made():
  expenses=[]
  number_of_days=int(input("Enter the number of days:"))
  for i in range(number_of_days):
    day_name=input(f"Enter the day name:")

    seed_cost=int(input("Enter the seed cost:"))
    fertilizer_cost=int(input("Enter the fertilizer cost:"))
    labour_cost=int(input("Enter the labour cost:"))

    expenses.append([day_name,[seed_cost,fertilizer_cost,labour_cost]])
  return expenses

total_expenditure = expenses_made()
print("DAILY EXPENSES")
for expenditure in total_expenditure:
  print(expenditure[0],"expenses are",expenditure[1],"total",)
  print(sum(expenditure[1]))
# Out:
# Enter the number of days:2
# Enter the day name:day1
# Enter the seed cost:100
# Enter the fertilizer cost:200
# Enter the labour cost:300
# Enter the day name:day 2
# Enter the seed cost:700
# Enter the fertilizer cost:600
# Enter the labour cost:700
# DAILY EXPENSES
# day1 expenses are [100, 200, 300] total
# 600
# day 2 expenses are [700, 600, 700] total
# 2000
