# %%
seasons=["Summer","winter","Autumn","Spring", "Rainy"]
print(seasons[-2])
# Out:
# Spring

# %%
seasons=["Summer","winter","Autumn","Spring", "Rainy"]
print(seasons[2:5])
# Out:
# ['Autumn', 'Spring', 'Rainy']

# %%
seasons=["Summer","winter","Autumn","Spring", "Rainy"]
print(seasons[1:5])
# Out:
# ['winter', 'Autumn', 'Spring', 'Rainy']

# %%
seasons=["Summer","winter","Autumn","Spring", "Rainy"]
print(seasons[:3])
# Out:
# ['Summer', 'winter', 'Autumn']

# %%
seasons=["Summer","winter","Autumn","Spring", "Rainy"]
print(seasons[2:])
# Out:
# ['Autumn', 'Spring', 'Rainy']

# %%
seasons=["Summer","winter","Autumn","Spring", "Rainy"]
print(seasons[-4:-1])
# Out:
# ['winter', 'Autumn', 'Spring']

# %%
seasons=["Summer","winter","Autumn","Spring", "Rainy"]
print(seasons[-1:-3]) #[-1:-3] it is like [start,end] andthe end element does not get printed ..so only empty list has come in the output
# Out:
# []

# %%
seasons=["Summer","winter","Autumn","Spring", "Rainy"]
print(seasons[-2:-1])
# Out:
# ['Spring']

# %%
seasons=["Summer","winter","Autumn","Spring", "Rainy"]
print(seasons[-1:])
# Out:
# ['Rainy']

# %%
seasons=["Summer","winter","Autumn","Spring", "Rainy"]
print(seasons[:-1])
# Out:
# ['Summer', 'winter', 'Autumn', 'Spring']

# %%
vegetables=["Carrot","Potato","Onion","Cucumber", "Pummpkin"]
vegetables[3]="Garlic"
print(vegetables)
# Out:
# ['Carrot', 'Potato', 'Onion', 'Garlic', 'Pummpkin']

# %%
vegetables=["Carrot","Potato","Onion","Cucumber", "Pummpkin"]
vegetables[2:4]=["Beetroot","Tomato"]
print(vegetables)
# Out:
# ['Carrot', 'Potato', 'Beetroot', 'Tomato', 'Pummpkin']

# %%
vegetables=["Carrot","Potato","Onion","Cucumber", "Pummpkin"]
vegetables[2:5]=["Beetroot","Tomato","Capsicum"]
print(vegetables)
# Out:
# ['Carrot', 'Potato', 'Beetroot', 'Tomato', 'Capsicum']

# %%
vegetables=["Carrot","Potato","Onion","Cucumber", "Pumpkin"]
vegetables[4:3]=["Beetroot","Tomato","Capsicum"] #when the start bumbeer is greater than the end number..in the output it displays or acts as insertv method
print(vegetables)
# Out:
# ['Carrot', 'Potato', 'Onion', 'Cucumber', 'Beetroot', 'Tomato', 'Capsicum', 'Pummpkin']

# %%
vegetables=["Carrot","Potato","Onion","Cucumber", "Pumpkin"]
vegetables[1:2]=["Capsicum"]
print(vegetables)
# Out:
# ['Carrot', 'Capsicum', 'Onion', 'Cucumber', 'Pumpkin']

# %%
vegetables=["Carrot","Potato","Onion","Cucumber", "Pumpkin"]
vegetables[2:1]=["Capsicum"]
print(vegetables)
# Out:
# ['Carrot', 'Potato', 'Capsicum', 'Onion', 'Cucumber', 'Pumpkin']

# %%
vegetables=["Carrot","Potato","Onion","Cucumber", "Pumpkin"]
vegetables[1:1]=["Capsicum"]
print(vegetables)
# Out:
# ['Carrot', 'Capsicum', 'Potato', 'Onion', 'Cucumber', 'Pumpkin']

# %%
vegetables=["Carrot","Potato","Onion","Cucumber", "Pumpkin"]
vegetables.insert(3,"Capsicum")
print(vegetables)
# Out:
# ['Carrot', 'Potato', 'Onion', 'Capsicum', 'Cucumber', 'Pumpkin']

# %%
vegetables=["Carrot","Potato","Onion","Cucumber", "Pumpkin"]
vegetables.append("Capsicum")
print(vegetables)
# Out:
# ['Carrot', 'Potato', 'Onion', 'Cucumber', 'Pumpkin', 'Capsicum']

# %%
vegetables=["Carrot","Potato","Onion","Cucumber", "Pumpkin"]

print(vegetables)
