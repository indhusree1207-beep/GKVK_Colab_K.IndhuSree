# %%
def expenses_made():
    expenses=[]
    number_of_days=int(input("Enter the number of working days:"))
    for i in range(number_of_days):
        day_name=input(f"Enter the day name:")

        seed_cost=int(input("Enter the seed cost:"))
        fertilizer_cost=int(input("Enter the fertilizer cost:"))
        labour_cost=int(input("Enter the labour cost:"))

        expenses.append([day_name,[seed_cost,fertilizer_cost,labour_cost]])
    return expenses

total_expenditure = expenses_made()
print("\nDAILY EXPENSES")
for expenditure in total_expenditure:
  print(expenditure[0],"expenses are",expenditure[1],)
  print("\n TOTAL EXPENSES")
  print(sum(expenditure[1]))

  def crop_data():
    crop_info=[]
    number_of_crops=int(input("Enter the number of crops grown:"))
    for c in range(number_of_crops):
           crop_name=input("Enter the name of the crop cultivated:")
           season=input(f"Enter the season of cultivation:")
           expected_yield=int(input("Enter the expected yield(in kg/ha):"))

           crop_info.append([crop_name,[season,expected_yield]])
    return crop_info

crop_records=crop_data()
print("\n CROP RECORD",crop_records )

print("\n--- Crop Details ---")
for index, crop in enumerate(crop_record, start=1):
    print(f"{index}. Crop Name: {crop[0]}, Season: {crop[1][0]}, Expected Yield: {crop[1][1]} kg/hectare")
# Out:
# Enter the number of working days:2
# Enter the day name:Day 1
# Enter the seed cost:100
# Enter the fertilizer cost:200
# Enter the labour cost:300
# Enter the day name:Day 2
# Enter the seed cost:300
# Enter the fertilizer cost:200
# Enter the labour cost:400
#
# DAILY EXPENSES
# Day 1 expenses are [100, 200, 300]
#
#  TOTAL EXPENSES
# 600
# Day 2  expenses are [300, 200, 400]
#
#  TOTAL EXPENSES
# 900
# Enter the number of crops grown:2
# Enter the name of the crop cultivated:Rice
# Enter the season of cultivation:Kharif
# Enter the expected yield(in kg/ha):1000
# Enter the name of the crop cultivated:Wheat
# Enter the season of cultivation:Rabi
# Enter the expected yield(in kg/ha):2000
#
#  CROP RECORD [['Rice', ['Kharif', 1000]], ['Wheat', ['Rabi', 2000]]]
#
# --- Crop Details ---
# 1. Crop Name: Rice, Season: Kharif, Expected Yield: 1000 kg/hectare
# 2. Crop Name: Wheat, Season: Rabi, Expected Yield: 2000 kg/hectare
