# %%
rainfall = []   # empty list to store rainfall values

# Accept rainfall for 5 days
for i in range(5):
    value = float(input("Enter rainfall for day " + str(i+1) + ": "))
    rainfall.append(value)

# Calculate total and average rainfall
total_rainfall= sum(rainfall)

average = total / 5

# Display average
print("Average rainfall:", average)

# Check rainfall condition
if average >= 100:
    print("Sufficient rainfall")
else:
    print("Insufficient rainfall")
# Out:
# Enter rainfall for day 1: 56
# Enter rainfall for day 2: 66
# Enter rainfall for day 3: 57
# Enter rainfall for day 4: 86
# Enter rainfall for day 5: 97
# Average rainfall: 73.2
# Insufficient rainfall
