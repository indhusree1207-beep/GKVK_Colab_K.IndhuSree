# %%
import matplotlib.pyplot as plt
x=[1,2,3,4,5]
y=[10,20,25,30,40]
plt.plot(x,y)
plt.show()

# %%
import matplotlib.pyplot as plt
x=[1,2,3,4,5]
y=[10,25,20,30,40]

plt.plot(x,y,marker='o',
         linestyle='--',
         color='blue',
         linewidth=2,
         markersize=8,
         label='sales')

plt.title("Monthly Sales Trend")
plt.xlabel('Month')
plt.ylabel('Sales')
plt.legend()
plt.grid(True)
plt.show()

# %%
import matplotlib.pyplot as plt
x=[1,2,3,4,5]
y=[10,25,20,30,40]
plt.scatter(x,y)
plt.show()

# %%
import matplotlib.pyplot as plt
x=[1,2,3,4,5]
y=[10,25,20,30,40]
sizes=[50,100,200,300,150]
plt.scatter(x,y,sizes)
plt.show()

# %%
activities = ['Sle', 'Eat', 'Work', 'Play']
slices = [3, 8, 10, 13]

plt.plot(x,y,marker='o')
plt.title("Bar Chart Example")
plt.xlabel("Activity")
plt.ylabel("Hours")
plt.show()

# %%
activities = ['Sleep', 'Eat', 'Work', 'Play']
slices = [3, 8, 10, 13]

plt.plot(x,y,marker='s')
plt.title("Daily Activities Chart")
plt.xlabel("Activity")
plt.ylabel("Hours")
plt.show()

# %%
activities = ['Sleep', 'Eat', 'Work', 'Play']
slices = [3, 8, 10, 13]

plt.plot(x,y,marker='^')
plt.title("Daily Activities Chart")
plt.xlabel("Activity")
plt.ylabel("Hours")
plt.show()

# %%
activities = ['Sleep', 'Eat', 'Work', 'Play']
slices = [3, 8, 10, 13]

plt.plot(x,y,marker='v')
plt.title("Daily Activities Chart")
plt.xlabel("Activity")
plt.ylabel("Hours")
plt.show()

# %%
activities = ['Sleep', 'Eat', 'Work', 'Play']
slices = [3, 8, 10, 13]

plt.plot(x,y,marker='*')
plt.title("Daily Activities Chart")
plt.xlabel("Activity")
plt.ylabel("Hours")
plt.show()

# %%
activities = ['Sleep', 'Eat', 'Work', 'Play']
slices = [3, 8, 10, 13]

plt.plot(x,y,marker='+')
plt.title("Daily Activities Chart")
plt.xlabel("Activity")
plt.ylabel("Hours")
plt.show()

# %%
activities = ['Sleep', 'Eat', 'Work', 'Play']
slices = [3, 8, 10, 13]

plt.plot(x,y,marker='X')
plt.title("Daily Activities Chart")
plt.xlabel("Activity")
plt.ylabel("Hours")
plt.show()

# %%
activities = ['Sleep', 'Eat', 'Work', 'Play']
slices = [3, 8, 10, 13]

plt.plot(x,y,marker='.')
plt.title("Daily Activities Chart")
plt.xlabel("Activity")
plt.ylabel("Hours")
plt.show()

# %%
import matplotlib.pyplot as plt

# Data: Rainfall (mm) and Growth Height (cm)
rainfall = [50, 100, 150, 200, 250, 300]
growth = [10, 20, 25, 30, 35, 40]

plt.plot(x,y,marker='X',linestyle='-')
plt.title('Effect of Rainfall on Crop Growth')
plt.xlabel('Rainfall (mm)')
plt.ylabel('Growth Height (cm)')
plt.show()

# %%
import matplotlib.pyplot as plt

# Data: Rainfall (mm) and Growth Height (cm)
rainfall = [50, 100, 150, 200, 250, 300]
growth = [10, 20, 25, 30, 35, 40]

plt.plot(x,y,marker='X',linestyle='--')
plt.title('Effect of Rainfall on Crop Growth')
plt.xlabel('Rainfall (mm)')
plt.ylabel('Growth Height (cm)')
plt.show()

# %%
import matplotlib.pyplot as plt

# Data: Rainfall (mm) and Growth Height (cm)
rainfall = [50, 100, 150, 200, 250, 300]
growth = [10, 20, 25, 30, 35, 40]

plt.plot(x,y,marker='X',linestyle='-.')
plt.title('Effect of Rainfall on Crop Growth')
plt.xlabel('Rainfall (mm)')
plt.ylabel('Growth Height (cm)')
plt.show()

# %%
import matplotlib.pyplot as plt

# Data: Rainfall (mm) and Growth Height (cm)
rainfall = [50, 100, 150, 200, 250, 300]
growth = [10, 20, 25, 30, 35, 40]

plt.plot(x,y,marker='X',linestyle=':')
plt.title('Effect of Rainfall on Crop Growth')
plt.xlabel('Rainfall (mm)')
plt.ylabel('Growth Height (cm)')
plt.show()

# %%
import matplotlib.pyplot as plt

# Data: Rainfall (mm) and Growth Height (cm)
rainfall = [50, 100, 150, 200, 250, 300]
growth = [10, 20, 25, 30, 35, 40]

plt.plot(x,y,marker='X',linestyle='--',color='blue')
plt.title('Effect of Rainfall on Crop Growth')
plt.xlabel('Rainfall (mm)')
plt.ylabel('Growth Height (cm)')
plt.show()

# %%
import matplotlib.pyplot as plt

# Data: Rainfall (mm) and Growth Height (cm)
rainfall = [50, 100, 150, 200, 250, 300]
growth = [10, 20, 25, 30, 35, 40]

plt.plot(x,y,marker='X',linestyle='--',color='red')
plt.title('Effect of Rainfall on Crop Growth')
plt.xlabel('Rainfall (mm)')
plt.ylabel('Growth Height (cm)')
plt.show()

# %%
import matplotlib.pyplot as plt

# Data: Rainfall (mm) and Growth Height (cm)
rainfall = [50, 100, 150, 200, 250, 300]
growth = [10, 20, 25, 30, 35, 40]

plt.plot(x,y,marker='X',linestyle='--',color='green')
plt.title('Effect of Rainfall on Crop Growth')
plt.xlabel('Rainfall (mm)')
plt.ylabel('Growth Height (cm)')
plt.show()

# %%
import matplotlib.pyplot as plt

# Data: Rainfall (mm) and Growth Height (cm)
rainfall = [50, 100, 150, 200, 250, 300]
growth = [10, 20, 25, 30, 35, 40]

plt.plot(x,y,marker='X',linestyle='--',color='black')
plt.title('Effect of Rainfall on Crop Growth')
plt.xlabel('Rainfall (mm)')
plt.ylabel('Growth Height (cm)')
plt.show()

# %%
import matplotlib.pyplot as plt

# Data: Rainfall (mm) and Growth Height (cm)
rainfall = [50, 100, 150, 200, 250, 300]
growth = [10, 20, 25, 30, 35, 40]

plt.plot(x,y,marker='X',linestyle='--',color='yellow')
plt.title('Effect of Rainfall on Crop Growth')
plt.xlabel('Rainfall (mm)')
plt.ylabel('Growth Height (cm)')
plt.show()

# %%
import matplotlib.pyplot as plt

# Data: Rainfall (mm) and Growth Height (cm)
rainfall = [50, 100, 150, 200, 250, 300]
growth = [10, 20, 25, 30, 35, 40]

plt.plot(x,y,marker='X',linestyle='--',color='purple')
plt.title('Effect of Rainfall on Crop Growth')
plt.xlabel('Rainfall (mm)')
plt.ylabel('Growth Height (cm)')
plt.show()

# %%
import matplotlib.pyplot as plt

# Data: Rainfall (mm) and Growth Height (cm)
rainfall = [50, 100, 150, 200, 250, 300]
growth = [10, 20, 25, 30, 35, 40]

plt.plot(x,y,marker='X',linestyle='--',color='pink')
plt.title('Effect of Rainfall on Crop Growth')
plt.xlabel('Rainfall (mm)')
plt.ylabel('Growth Height (cm)')
plt.show()

# %%
import matplotlib.pyplot as plt

# Data: Rainfall (mm) and Growth Height (cm)
rainfall = [50, 100, 150, 200, 250, 300]
growth = [10, 20, 25, 30, 35, 40]

plt.plot(x,y,marker='X',linestyle='--',color='orange')
plt.title('Effect of Rainfall on Crop Growth')
plt.xlabel('Rainfall (mm)')
plt.ylabel('Growth Height (cm)')
plt.show()

# %%
import matplotlib.pyplot as plt

# Data: Rainfall (mm) and Growth Height (cm)
rainfall = [50, 100, 150, 200, 250, 300]
growth = [10, 20, 25, 30, 35, 40]

plt.plot(x,y,marker='X',linestyle='--',color='#00FFFF')     #cyan
plt.title('Effect of Rainfall on Crop Growth')
plt.xlabel('Rainfall (mm)')
plt.ylabel('Growth Height (cm)')
plt.show()

# %%
import matplotlib.pyplot as plt

# Data: Rainfall (mm) and Growth Height (cm)
rainfall = [50, 100, 150, 200, 250, 300]
growth = [10, 20, 25, 30, 35, 40]

plt.plot(x,y,marker='X',linestyle='--',color=(0.5,0.6,0.7))     #  RGB Tuple
plt.title('Effect of Rainfall on Crop Growth')
plt.xlabel('Rainfall (mm)')
plt.ylabel('Growth Height (cm)')
plt.show()

# %%
import matplotlib.pyplot as plt

# Data: Rainfall (mm) and Growth Height (cm)
rainfall = [50, 100, 150, 200, 250, 300]
growth = [10, 20, 25, 30, 35, 40]

plt.plot(x,y,marker='X',linestyle='--',color='green',label='growth')
plt.legend()
plt.title('Effect of Rainfall on Crop Growth')
plt.xlabel('Rainfall (mm)')
plt.ylabel('Growth Height (cm)')
plt.show()

# %%
import matplotlib.pyplot as plt

# Data: Rainfall (mm) and Growth Height (cm)
rainfall = [50, 100, 150, 200, 250, 300]
growth = [10, 20, 25, 30, 35, 40]

plt.plot(x,y,marker='X',linestyle='--',color='green')
plt.title('Effect of Rainfall on Crop Growth')
plt.xlabel('Rainfall (mm)')
plt.ylabel('Growth Height (cm)')
plt.show()

# %%
import matplotlib.pyplot as plt

# Data: Rainfall (mm) and Growth Height (cm)
rainfall = [50, 100, 150, 200, 250, 300]
growth = [10, 20, 25, 30, 35, 40]

plt.plot(x,y,'o--g')
plt.title('Effect of Rainfall on Crop Growth')
plt.xlabel('Rainfall (mm)')
plt.ylabel('Growth Height (cm)')
plt.show()

# %%
import matplotlib.pyplot as plt

# Data: Rainfall (mm) and Growth Height (cm)
rainfall = [50, 100, 150, 200, 250, 300]
growth = [10, 20, 25, 30, 35, 40]

plt.plot(x,y,'X-.k')    # Marker + Linestyle + Color
plt.title('Effect of Rainfall on Crop Growth')
plt.xlabel('Rainfall (mm)')
plt.ylabel('Growth Height (cm)')
plt.show()

# %%
import matplotlib.pyplot as plt

# Data: Rainfall (mm) and Growth Height (cm)
rainfall = [50, 100, 150, 200, 250, 300]
growth = [10, 20, 25, 30, 35, 40]

plt.plot(x,y,'X-.b')
plt.title('Effect of Rainfall on Crop Growth')
plt.xlabel('Rainfall (mm)')
plt.ylabel('Growth Height (cm)')
plt.show()

# %%
import matplotlib.pyplot as plt

rainfall = [50, 100, 150, 200, 250, 300]
growth = [10, 20, 25, 30, 35, 40]
yields=[25,56,86,45,97,67]

plt.plot(rainfall, growth, label='growth')
plt.plot(rainfall, yields, label='yields')

plt.title('Effect of Rainfall on Crop Growth')
plt.legend()
plt.show()

# %%
import matplotlib.pyplot as plt

rainfall = [50, 100, 150, 200, 250, 300]
growth = [10, 20, 25, 30, 35, 40]

plt.plot(x,y,marker='o',linestyle='-.',color='green',linewidth=5,markersize=10,label='growth')
plt.title('Effect of Rainfall on Crop Growth')
plt.xlabel('Rainfall (mm)')
plt.ylabel('Growth Height (cm)')
plt.show()

# %%
import matplotlib.pyplot as plt

rainfall = [50, 100, 150, 200, 250, 300]
growth = [10, 20, 25, 30, 35, 40]

plt.title('Effect of Rainfall on Crop Growth')
sizes=[50,100,200,300,550]
plt.scatter(x,y,s=sizes)
plt.show()

# %%
import matplotlib.pyplot as plt

rainfall = [50, 100, 150, 200, 250, 300]
growth = [10, 20, 25, 30, 35, 40]

plt.title('Effect of Rainfall on Crop Growth')
sizes=[50,100,200,300,550]
plt.scatter(x,y,c='blue')
plt.show()

# %%
import matplotlib.pyplot as plt

rainfall = [50, 100, 150, 200, 250, 300]
growth = [10, 20, 25, 30, 35, 40]

plt.title('Effect of Rainfall on Crop Growth')
colors=['red','blue','green','purple','orange']
plt.scatter(x,y,c=colors)
plt.show()

# %%
import matplotlib.pyplot as plt

rainfall = [50, 100, 150, 200, 250, 300]
growth = [10, 20, 25, 30, 35, 40]

plt.title('Effect of Rainfall on Crop Growth')
# Adjusted values to match the length of x and y
values=[1,2,3,4,5]
plt.scatter(x,y,c=values)
plt.show()

# %%
import matplotlib.pyplot as plt

rainfall = [50, 100, 150, 200, 250, 300]
growth = [10, 20, 25, 30, 35, 40]

plt.title('Effect of Rainfall on Crop Growth')
sizes=[50,100,200,300,550]
colors=['red','blue','green','purple','orange']
plt.scatter(x,y,s=sizes,c=colors)
plt.show()

# %%
import matplotlib.pyplot as plt
import numpy as np

x=np.random.rand(50)
y=np.random.rand(50)
sizes=1000*np.random.rand(50)
colors=np.random.rand(50)

plt.scatter(x,y,s=sizes,c=colors,cmap='viridis',alpha=0.6)
plt.colorbar()
plt.title("Advanced Scatter Plot")
plt.xlabel("X values")
plt.ylabel("Y values")
plt.show()

# %%
import matplotlib.pyplot as plt
import numpy as np

x=np.random.rand(50)
y=np.random.rand(50)
sizes=1000*np.random.rand(50)
colors=np.random.rand(50)

plt.scatter(x,y,s=sizes,c=colors,cmap='plasma',alpha=0.8)
plt.colorbar()
plt.title("Advanced Scatter Plot")
plt.xlabel("X values")
plt.ylabel("Y values")
plt.show()

# %%
import matplotlib.pyplot as plt
import numpy as np

x=np.random.rand(50)
y=np.random.rand(50)
sizes=1000*np.random.rand(50)
colors=np.random.rand(50)

plt.scatter(x,y,s=sizes,c=colors,cmap='inferno',alpha=0.8)
plt.colorbar()
plt.title("Advanced Scatter Plot")
plt.xlabel("X values")
plt.ylabel("Y values")
plt.show()

# %%
import matplotlib.pyplot as plt
import numpy as np

x=np.random.rand(50)
y=np.random.rand(50)
sizes=1000*np.random.rand(50)
colors=np.random.rand(50)

plt.scatter(x,y,s=sizes,c=colors,cmap='cividis',alpha=0.8)
plt.colorbar()
plt.title("Advanced Scatter Plot")
plt.xlabel("X values")
plt.ylabel("Y values")
plt.show()

# %%
import matplotlib.pyplot as plt
import numpy as np

x=np.random.rand(50)
y=np.random.rand(50)
sizes=1000*np.random.rand(50)
colors=np.random.rand(50)

plt.scatter(x,y,s=sizes,c=colors,cmap='magma',alpha=0.8)
plt.colorbar()
plt.title("Advanced Scatter Plot")
plt.xlabel("X values")
plt.ylabel("Y values")
plt.show()

# %% [markdown]
# **BAR GRAPHS**

# %%
import matplotlib.pyplot as plt
import numpy as np

x=np.array(["A","B","C","D","E"])
y=np.array([3,8,1,10,12])

plt.bar(x,y)
plt.show()

# %%
import matplotlib.pyplot as plt
import numpy as np

x=["APPLES","BANANAS","KIWI"]
y=[400,350,110]

plt.bar(x,y)
plt.show()

# %% [markdown]
# **HORIZONTAL BARS **

# %%
import matplotlib.pyplot as plt
import numpy as np

x=np.array(["A","B","C","D","E"])
y=np.array([3,8,1,10,12])

plt.barh(x,y)
plt.show()

# %%
import matplotlib.pyplot as plt
import numpy as np

x=np.array(["A","B","C","D","E"])
y=np.array([3,8,1,10,12])

plt.bar(x,y,color='red')
plt.show()

# %%
import matplotlib.pyplot as plt
import numpy as np

x=np.array(["A","B","C","D","E"])
y=np.array([3,8,1,10,12])

plt.bar(x,y,color='hotpink')
plt.show()

# %%
import matplotlib.pyplot as plt
import numpy as np

x=np.array(["A","B","C","D","E"])
y=np.array([3,8,1,10,12])

plt.bar(x,y,color= 'chartreuse')
plt.show()

# %%
import matplotlib.pyplot as plt
import numpy as np

x=np.array(["A","B","C","D","E"])
y=np.array([3,8,1,10,12])

plt.bar(x,y,color='burlywood')
plt.savefig("filename")
plt.show()

# %%
import matplotlib.pyplot as plt
import numpy as np

x=np.array(["A","B","C","D","E"])
y=np.array([3,8,1,10,12])

plt.bar(x,y,color='xkcd:pastel purple')   # It also includes over 900 XKCD colors when prefixed with 'xkcd:'
plt.show()

# %%
import matplotlib.pyplot as plt
import numpy as np

x=np.array(["A","B","C","D","E"])
y=np.array([3,8,1,10,12])

plt.bar(x,y,color='xkcd:pastel purple')
plt.twinx()
plt.show()

# %%
import matplotlib.pyplot as plt
import numpy as np

x=np.array(["A","B","C","D","E"])
y=np.array([3,8,1,10,12])

plt.barh(x,y,height=0.1)
plt.show()

# %%
import matplotlib.pyplot as plt
import numpy as np

x=np.array(["A","B","C","D","E"])
y=np.array([3,8,1,10,12])


plt.barh(x,y,height=0.8,color='orange','blue','green','pink','yellow')
plt.show()

# %%
import matplotlib.pyplot as plt
import numpy as np

x=np.random.normal(170,10,250)
plt.hist(x)
plt.show()

# %%
import matplotlib.pyplot as plt
import numpy as np

data=np.random.normal(170,10,250)

plt.hist(data,bins=20)   # Bins---> Frequency


plt.xlabel("Value")
plt.ylabel("Frequency")
plt.title("Histogram Example")
plt.show()

# %%
import matplotlib.pyplot as plt
data=[2,3,5,7,8,
      10,12,13,15,17,
      18,20,22,24,25,
      27,29,30,32,35]
plt.hist(data,bins=10,edgecolor='black')
plt.title("Histogram with 5 bins ")
plt.show()

# %%
import matplotlib.pyplot as plt
import numpy as np

data=np.random.normal(170,10,250)

plt.hist(data,bins=40)

plt.xlabel("Value")
plt.ylabel("Frequency")
plt.title("Histogram Example")
plt.show()

# %%
import matplotlib.pyplot as plt
data=[
    30,35,40,42,45,47,48,49,
    50,50,51,52,53,55,57,60,
    62,65,70,75
]
plt.figure(figsize=(8,5))
plt.hist(
    data,bins=5,color='blue',
    edgecolor='black',
    alpha=0.5,density=True,
    range=(30,80)
)
plt.xlabel("Value")
plt.ylabel("Density")
plt.title("Histogram without random data")
plt.grid(True)
plt.tight_layout()
plt.show()

# %%
import matplotlib.pyplot as plt
import numpy as np
# plot 1
x=np.array([0,1,2,3])
y=np.array([3,8,1,10])
plt.subplot(1,2,1)
plt.plot(x,y)

# plot 2
y=np.array([10,20,30,40])

plt.subplot(1,2,2)
plt.plot(x,y)
plt.show()

# %% [markdown]
# **DRAWING TWO PLOTS ON EACH OTHER **

# %%
import matplotlib.pyplot as plt
import numpy as np
# plot 1
x=np.array([0,1,2,3])
y=np.array([3,8,1,10])
plt.subplot(2,1,1)
plt.plot(x,y)

# plot 2
x=np.array([0,1,2,3])
y=np.array([10,20,30,40])

plt.subplot(2,1,2)
plt.plot(x,y)
plt.show()

# %%
import matplotlib.pyplot as plt
import numpy as np
# plot 1
x=np.array([0,1,2,3])
y=np.array([3,8,1,10])
plt.subplot(1,2,1)
plt.plot(x,y)

# plot 2
x=np.array([0,1,2,3])
y=np.array([10,20,30,40])

plt.subplot(1,2,1)
plt.plot(x,y)
plt.show()

# %%
import matplotlib.pyplot as plt
import numpy as np

x=np.array([0,1,2,3])
y=np.array([3,8,1,10])
plt.subplot(2,3,1)
plt.plot(x,y)

# plot 2
x=np.array([0,1,2,3])
y=np.array([10,20,30,40])

plt.subplot(2,3,2)
plt.plot(x,y)

# plot 2
x=np.array([0,1,2,3])
y=np.array([10,20,30,40])

plt.subplot(2,3,3)
plt.plot(x,y)

x=np.array([0,1,2,3])
y=np.array([3,8,1,10])
plt.subplot(2,3,4)
plt.plot(x,y)

x=np.array([0,1,2,3])
y=np.array([10,20,30,40])

plt.subplot(2,3,5)
plt.plot(x,y)
plt.show()

# %%
import matplotlib.pyplot as plt
import numpy as np

x=np.array([0,1,2,3])
y=np.array([3,8,1,10])
plt.subplot(2,3,1)
plt.plot(x,y)

x=np.array([13,5,7,9])
y=np.array([10,20,30,40])
plt.subplot(2,3,2)
plt.plot(x,y)

x=np.array([3,6,9,12])
y=np.array([10,20,30,40])
plt.subplot(2,3,3)
plt.plot(x,y)

x=np.array([8,6,4,2])
y=np.array([3,8,1,10])
plt.subplot(2,3,4)
plt.plot(x,y)

x=np.array([1,2,5,7])
y=np.array([10,20,30,40])
plt.subplot(2,3,5)
plt.plot(x,y)
plt.show()

# %%
import matplotlib.pyplot as plt
import numpy as np

x=np.array([0,1,2,3])
y=np.array([3,8,1,10])
plt.subplot(2,3,1)
plt.plot(x,y)

x=np.array([0,1,2,3])
y=np.array([10,20,30,40])
plt.subplot(2,3,2)
plt.barh(x,y,height=0.5)

x=np.array([0,1,2,3])
y=np.array([10,20,30,40])
plt.subplot(2,3,3)
plt.bar(x,y,color='orange')

x=np.array([0,1,2,3])
y=np.array([3,8,1,10])
plt.subplot(2,3,4)
plt.hist(x,bins=10,edgecolor='black')

data=[
    30,35,40,42,45,47,48,49,
    50,50,51,52,53,55,57,60,
    62,65,70,75
]
plt.figure(figsize=(8,5))
plt.hist(
    data,bins=5,color='blue',
    edgecolor='black',
    alpha=0.5,density=True,
    range=(30,80)
)
plt.xlabel("Value")
plt.ylabel("Density")
plt.title("Histogram without random data")
plt.grid(True)
plt.tight_layout()
plt.subplot(2,3,5)

plt.show()

# %%
import matplotlib.pyplot as plt
import numpy as np

sizes = np.array([35, 25, 25, 15])
labels = ["Apples", "Bananas", "Cherries", "Dates"]

plt.pie(sizes, labels=labels)

plt.title("Fruit Preferences")

plt.axis('equal')

plt.show()
